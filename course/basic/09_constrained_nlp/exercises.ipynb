# %% [markdown]
# # Lesson 9 — Exercises

# %% [markdown]
# ## Exercise 1 — KKT by hand (15 pts)
#
# Write the KKT system for $\min x_1^2 + x_2^2$ s.t. $x_1 + x_2 \ge 1, x_1 \ge 0, x_2 \ge 0$. Solve algebraically. Verify against `discopt`.

# %%
# discopt course compat shim — installs `add_variable / add_variables /
# add_constraint / add_constraints / is_convex` and a friendly `.solve(...)`
# on `discopt.Model`. Run this cell first.
import sys, pathlib
_repo = pathlib.Path.cwd()
while _repo != _repo.parent and not (_repo / "course").is_dir(): _repo = _repo.parent
if str(_repo) not in sys.path: sys.path.insert(0, str(_repo))
from course._compat import *  # noqa: F401,F403

# %%
# TODO

# %% [markdown]
# ## Exercise 2 — When KKT fails (15 pts)
#
# Construct a problem where LICQ fails at the optimum (e.g., $\min x_1$ s.t. $-x_1^3 + x_2 \le 0, -x_2 \le 0$ at the origin). Show that no finite multipliers satisfy KKT. What happens when you try to solve it?

# %%
# TODO

# %% [markdown]
# ## Exercise 3 — Walk the central path (15 pts)
#
# For the circle problem in the reading, solve with $\mu = 10, 1, 0.1, 0.01, 0.001$ (you may have to drop into `discopt`'s low-level IPM API). Plot the central-path iterates approaching the optimum on the unit circle.

# %%
# TODO

# %% [markdown]
# ## Exercise 4 — Equality constrained quadratic (15 pts)
#
# For $\min \tfrac{1}{2} x^\top Q x + c^\top x$ s.t. $Ax = b$, derive the closed-form KKT system and solve it directly with a single linear solve. Check against `discopt`'s solver. (Use $Q = I_3$, $c = (1, 2, 3)^\top$, $A = (1, 1, 1)$, $b = 1$.)

# %%
# TODO

# %% [markdown]
# ## Exercise 5 — Slater's condition (10 pts)
#
# Give an example of a convex problem where Slater's condition *fails*. Try to solve it; do you still get a finite optimum? What does this say about the necessity vs sufficiency of CQs?

# %%
# TODO
