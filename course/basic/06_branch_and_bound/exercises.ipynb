# %% [markdown]
# # Lesson 6 — Exercises

# %% [markdown]
# ## Exercise 1 — Trace by hand (15 pts)
#
# For the 4-item knapsack in the reading, draw the B&B tree by hand (with LP value at each node, the branching variable, and pruning reasons). The tree should have at most 7 nodes. Compare with `discopt`'s log.

# %% [markdown]
# **Your tree:**
# ```
# [draw it here in text or attach a PNG]
# ```

# %% [markdown]
# ## Exercise 2 — Bound vs branch (15 pts)
#
# Generate a knapsack with $n = 30$ items, two ways:
#
# (a) **Easy**: weights $\sim$ Uniform(1, 10), values $\sim$ Uniform(1, 10).
# (b) **Hard**: values $=$ weights (degenerate).
#
# Solve both, compare nodes, LP gap, and runtime. Why is (b) so much harder?

# %%
# discopt course compat shim — installs `add_variable / add_variables /
# add_constraint / add_constraints / is_convex` and a friendly `.solve(...)`
# on `discopt.Model`. Run this cell first.
import sys, pathlib
_repo = pathlib.Path.cwd()
while _repo != _repo.parent and not (_repo / "course").is_dir(): _repo = _repo.parent
if str(_repo) not in sys.path: sys.path.insert(0, str(_repo))
from course._compat import *  # noqa: F401,F403

# %%
# TODO

# %% [markdown]
# ## Exercise 3 — Node selection (10 pts)
#
# Solve the same MILP with three node-selection strategies (best-first, depth-first, best-estimate). Compare nodes processed and time-to-first-incumbent. When would you prefer each?

# %%
# TODO

# %% [markdown]
# ## Exercise 4 — Symmetry (15 pts)
#
# Construct a small MILP where the variables $x_1, x_2, x_3$ are completely symmetric (e.g., bin packing with 3 identical bins). Solve as-is, then add a *lex-ordering* tightening (e.g., $x_1 \le x_2 \le x_3$ if applicable). Compare node counts.

# %%
# TODO

# %% [markdown]
# ## Exercise 5 — When does B&B finish in one node? (15 pts)
#
# Give an example MILP whose LP relaxation has an integer optimum (so B&B prunes by integrality at the root). What structural property of your matrix is responsible?

# %%
# TODO
