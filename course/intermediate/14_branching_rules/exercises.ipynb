# %% [markdown]
# # Lesson 14 — Exercises

# %% [markdown]
# ## Exercise 1 — Implement strong branching (20 pts)
#
# Write a `discopt` branching callback that performs strong branching on the top-5 most fractional candidates (each with a 50-iteration LP cap). Compare nodes vs default on a 50-item hard knapsack.

# %%
# discopt course compat shim — installs `add_variable / add_variables /
# add_constraint / add_constraints / is_convex` and a friendly `.solve(...)`
# on `discopt.Model`. Run this cell first.
import sys, pathlib
_repo = pathlib.Path.cwd()
while _repo != _repo.parent and not (_repo / "course").is_dir(): _repo = _repo.parent
if str(_repo) not in sys.path: sys.path.insert(0, str(_repo))
from course._compat import *  # noqa: F401,F403

# %%
# TODO

# %% [markdown]
# ## Exercise 2 — Pseudocost from scratch (15 pts)
#
# Implement pseudocost branching as a callback. Track $\Phi^+, \Phi^-$ globally; update after each branching. Compare to most-fractional.

# %%
# TODO

# %% [markdown]
# ## Exercise 3 — Reliability tuning (15 pts)
#
# Implement reliability branching with a tunable threshold $K$ (number of branchings before pseudocost is 'reliable'). For $K \in \{1, 5, 25\}$, report node counts on a benchmark instance.

# %%
# TODO

# %% [markdown]
# ## Exercise 4 — When most-fractional wins (10 pts)
#
# Construct (or find) an MILP where most-fractional branching beats strong branching. Possibly: a problem where strong branching's overhead per node dwarfs the savings.

# %%
# TODO

# %% [markdown]
# ## Exercise 5 — Direction matters (10 pts)
#
# Using default branching, run two times: down-first and up-first. Does it matter for nodes? For time-to-first-incumbent? Why?

# %%
# TODO
