# %% [markdown]
# # Lesson 21 — Exercises

# %% [markdown]
# ## Exercise 1 — Trace a spatial-B&B node (15 pts)
#
# For $\min x y$ s.t. $x + y \ge 1, x, y \in [0, 2]$, solve the McCormick relaxation by hand at the root box. Then branch $x$ at $1$ and resolve both children. Record bounds at each step; verify the global optimum.

# %%
# discopt course compat shim — installs `add_variable / add_variables /
# add_constraint / add_constraints / is_convex` and a friendly `.solve(...)`
# on `discopt.Model`. Run this cell first.
import sys, pathlib
_repo = pathlib.Path.cwd()
while _repo != _repo.parent and not (_repo / "course").is_dir(): _repo = _repo.parent
if str(_repo) not in sys.path: sys.path.insert(0, str(_repo))
from course._compat import *  # noqa: F401,F403

# %%
# TODO

# %% [markdown]
# ## Exercise 2 — OBBT vs no-BBT (15 pts)
#
# For a 3-bilinear MINLP of your choice, solve `mode='global'` (i) with OBBT enabled, (ii) disabled. Compare nodes and time.

# %%
# TODO

# %% [markdown]
# ## Exercise 3 — Branching rule comparison (15 pts)
#
# Swap between `branching='most_violated'` and `branching='longest_edge'` on the same problem. Compare nodes.

# %%
# TODO

# %% [markdown]
# ## Exercise 4 — Build your own (20 pts)
#
# Implement a *minimal* spatial B&B in ~150 lines: McCormick at each node, depth-first node selection, midpoint branching. Test on 3 small bilinear NLPs.

# %%
# TODO

# %% [markdown]
# ## Exercise 5 — Diagnose stalled gap (5 pts)
#
# Pick a MINLP whose gap doesn't close after 5,000 nodes. Diagnose: is it bounds, symmetry, or convex-envelope tightness?

# %% [markdown]
# **Your diagnosis:** ...
