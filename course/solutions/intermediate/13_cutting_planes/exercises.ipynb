# %% [markdown]
# # Lesson 13 — solutions

# %% [markdown]
# **E5.** A simple cover-cut routine: for each knapsack constraint, greedily add items in decreasing order of $w_i x_i^{LP}$ until the cover is reached; emit the cut. Production solvers use lifted cover cuts; this is a starting point.
