# %% [markdown]
# # Lesson 11 solutions — implementation outlines

# %% [markdown]
# **E2.** Two-phase: introduce artificial variables $a$, minimize $\sum a_i$ in Phase 1; if optimum is 0, drop artificials and resume with original $c$ in Phase 2.
#
# **E4.** Beale's example: $\min -\tfrac{3}{4}x_4 + 150 x_5 - \tfrac{1}{50} x_6 + 6 x_7$ s.t. ...
