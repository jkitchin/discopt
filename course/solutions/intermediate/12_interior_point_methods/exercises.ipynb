# %% [markdown]
# # Lesson 12 — outlines
#
# Full IPM in ~80 lines is feasible: implement the normal-equations system with `scipy.linalg.cho_solve`, line search via $\alpha_p = \min(1, 0.99 \cdot \min_i -x_i/\Delta x_i)$ on positive coordinates, similarly for $\alpha_d$.
