# %% [markdown]
# # Lesson 16 — outlines

# %% [markdown]
# **E1.** Inequalities tight at the four corners $(1,-2),(1,4),(3,-2),(3,4)$. Loosest at center $(2, 1)$.
#
# **E5.** Gap scales as $\Theta(b^2)$ since both terms scale with $b$.
