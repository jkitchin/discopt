# %% [markdown]
# # Lesson 17 — outlines

# %% [markdown]
# **E1.** Lasso → introduce $t \ge \|Ax - b\|_2$ (SOC) and $u_i \ge |x_i|$ (LP), minimize $t + \lambda \sum u_i$.
#
# **E5.** Robust constraint $a^\top x \ge b$ for all $a \in \bar a + P u, \|u\| \le 1$ becomes $\bar a^\top x - \|P^\top x\| \ge b$ (SOC).
