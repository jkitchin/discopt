# %% [markdown]
# # Capstone (intermediate) — assessor notes
#
# No single solution. Look for: clean callback code, statistically-sound benchmarking, honest discussion of when the new method helps and when it doesn't.
