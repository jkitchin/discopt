# %% [markdown]
# # Lesson 7 solutions

# %% [markdown]
# **E1.** a) neither — indefinite Hessian. b) convex — exp-affine + sum of even-power monomials. c) convex — max of convex. d) neither — vanishing curvature, then concave at infinity.
