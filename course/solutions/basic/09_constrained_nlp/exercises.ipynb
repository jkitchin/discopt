# %% [markdown]
# # Lesson 9 solutions

# %% [markdown]
# **E1.** KKT: $2 x_i + \lambda - \nu_i = 0, x_1 + x_2 \ge 1, x_i \ge 0, \lambda, \nu_i \ge 0,$ complementary slackness. Interior solution: $\nu = 0, x_1 = x_2 = 1/2, \lambda = -1$ violates $\lambda \ge 0$ — wait. Sign convention check: for $g_i(x) \le 0$ form, we have $-(x_1+x_2) + 1 \le 0$, multiplier $\lambda \ge 0$, gradient $(-1, -1)$, so $2x_i - \lambda = 0$, $\lambda = 2 x_i$, $x_1 = x_2 = 1/2, \lambda = 1$. Optimum $f^\star = 1/2$.

# %%
# discopt course compat shim — installs `add_variable / add_variables /
# add_constraint / add_constraints / is_convex` and a friendly `.solve(...)`
# on `discopt.Model`. Run this cell first.
import sys, pathlib
_repo = pathlib.Path.cwd()
while _repo != _repo.parent and not (_repo / "course").is_dir(): _repo = _repo.parent
if str(_repo) not in sys.path: sys.path.insert(0, str(_repo))
from course._compat import *  # noqa: F401,F403
