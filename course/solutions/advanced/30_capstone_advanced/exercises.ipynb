# %% [markdown]
# # Capstone (advanced) — assessor notes
#
# Look for genuine novelty (even small), honest experiments with confidence intervals, clear writing, and reproducibility. A null result well-explained beats a positive result poorly investigated.
